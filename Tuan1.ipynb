# %%
# bai 1
import matplotlib.pyplot as plt
import numpy as np 

x = [1,2,3,4]
y = [1,4,9,16]

plt.figure(figsize=(15,5)) # kích thước chiều rộng chiều cao của sơ đồ

plt.title("Do thi")

plt.xlabel("Truc Ox")
plt.ylabel("Truc Oy")

plt.plot(x,y, "bo")
plt.show()

# %%
#bai 2 vẽ hai đồ thị
import matplotlib.pyplot as plt
import numpy as np
#kích thước đồ thị thứ nhất
x1=[1,2,3,4]
y1=[1,4,9,16]
#kích thước đồ thị thứ 2
x2=[1,2,3,4]
y2=[i**3 for i in x2] #i mũ 3 chạy trong khoảng x

plt.title("Hai đồ thị")

plt.xlabel("Trục Ox")
plt.ylabel("Trục Oy")

plt.plot(x1, y1, "bo", x2, y2,"r^")
plt.show()

# %%
#bài 3 vẽ sơ đồ 1 dòng 2 cột
import matplotlib.pyplot as plt
import numpy as np

x1 = [1,2,3,4]
y1 = [1,4,9,16]

x2 = [1,2,3,4]
y2 = [i**3 for i in x2]

plt.subplot(1,2,1)
plt.plot(x1,y1, "go")
plt.title("Cột 1")

plt.subplot(1,2,2)
plt.plot(x2,y2,"r^")
plt.title("Cột 2")

plt.suptitle("Hiển thị 1 dòng 2 cột")
# Out:
# Text(0.5, 1.0, 'Cột 2')

# %%
#bài 4 vẽ sơ đồ 2 dòng 1 cột 
import matplotlib.pyplot as plt
import numpy as np

x1 = [1,2,3,4]
y1 = [1,4,9,16]

x2=[1,2,3,4]
y2=[i**3 for i in x2]

plt.subplot(2,1,1) 
plt.plot(x1,y1, 'go')
plt.title("Dong 1")

plt.subplot(2,1,2) 
plt.plot(x2,y2, "r^")
plt.title("Dong 2")

plt.suptitle("Hien thi 2 dong 1 cot")
plt.show()

# %%
# vẽ sơ đồ 4 lưới
import matplotlib.pyplot as plt
import numpy as np

x1 = [1,2,3,4]
y1 = [1,4,9,16]

x2=[1,2,3,4]
y2=[i**3 for i in x2]

x3=[1,2,3,4]
y3=[2*i for i in x3]

fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(6,6)) #ax định vị khoảng vùng

ax[0,1].plot(x1,y1,"go")
ax[0,1].set_title("Mau xanh la")

ax[1,0].plot(x2,y2, "r^")
ax[1,0].set_title("Mau do")

ax[1,1].plot(x3,y3, "bo")
ax[1,1].set_title("Mau xanh duong")

plt.show()

# %%
# bài 5 vẽ scatterplot 
import matplotlib.pyplot as plt
import numpy as np

x = [10,20,30,50,0,70,80,90,100]
y = [2,8,6,4,12,18,16,20,10]

plt.scatter(x,y)
plt.xlabel("Trục Ox")
plt.ylabel("Trục Oy")
plt.show()

# %%
# vẽ scatterplot có bước nhảy
import matplotlib.pyplot as plt
import numpy as np

x = [20,30,50,60,70,80,90,100]
y = [8,6,4,12,18,16,20,10]

plt.xticks(range(0,100,5))
plt.yticks(range(0,20,1))

plt.scatter(x,y)
plt.xlabel("Ox")
plt.ylabel("Oy")

plt.show()

# %%
# bài 6 vẽ sơ đồ có giới hạn
import matplotlib.pyplot as plt
import numpy as np

x = [20,30,50,60,70,80,90,100]
y = [8,6,4,12,18,16,20,10]

plt.xlim(20,100)
plt.ylim(4,20)

plt.scatter(x,y)
plt.xlabel("Ox")
plt.ylabel("Oy")

plt.show()

# %%
# bài 7 vẽ biểu đồ tròn
import matplotlib.pyplot as plt

dailys = ['Dai ly A','Dai ly B','Dai ly C','Dai ly D','Dai ly E']

doanhthu = [20,25,15,10,20]

noibat = [0,0.1,0,0,0]

plt.pie(doanhthu, explode=noibat, labels=dailys, shadow=True, startangle=45)

plt.axis("equal")

plt.legend(title='danh sach dai ly')

plt.show()

# %%
#bài 8 sơ đồ gantt
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

ax.set_xlim(0,160)
ax.set_ylim(0,50)

ax.set_xlabel('Ngày công')
ax.set_ylabel('Dự án')


ax.set_yticks([15,25,35])
ax.set_yticklabels(['Dự án 1','Dự án 2', 'Dự án 3'])

ax.grid(True)

ax.broken_barh([(40,50)],(30,8), facecolors=('tab:orange'))
ax.broken_barh([(10,50),(100,20),(130,10)],(20,8), facecolors=('tab:red'))

ax.broken_barh([(20,10),(50,30), (100, 50)],(10,8), facecolors=('tab:blue'))

plt.show()

# %%
# bài 9 parabol
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5,5,1000)
y = x**2

plt.plot(x,y)
plt.show()

# %%
# bài 10 
import numpy as np
import matplotlib.pyplot as plt

A = np.array([[1,-2],[3,5]])
b =np.array([-1,8])

ketqua=np.linalg.solve(A,b)

print("X0 =", ketqua[0])
print("Y0 =", ketqua[1])

#Truc quan hoa

# Duong thang (1)

x1 =  np.linspace(-2,2,50)
y1 =  (x1+1)/2

# Duong thang 2)

x2 =  np.linspace(-2,2,50)
y2=  (-3*x2 + 8)/5

plt.plot(x1,y1,x2,y2)
plt.show()
# Out:
# X0 = 1.0
# Y0= 1.0

# %%
#bai 11 đạo hàm
from math import *
 
def f(x):
    return x**2
def derive(func, value):
        h = 0.0000000001
        tuso = func(value+h) - func(value)
        mauso = h
        
        return tuso/mauso
        
"""
Tinh gia tri cua dao ham f(x) = x^2 tai x0=1
"""
kq= derive(f,1)
print(kq)
# Out:
# 2.000000165480742

# %%
#bài 12 animate
import matplotlib.pyplot as plt

from matplotlib.animation import FuncAnimation

from random import randint

import numpy as np

fig, ax = plt.subplots()

data = np.linspace(-5,5,200)

ax.plot(data,data**2)

ax.set_xlim([-5,5])

ax.set_ylim([0,25])

pt, = plt.plot([-5],[25],'ro',ms=10)

def animate(i):

    x = data[i]

    y = x**2

    pt.set_data(x,y)

    #return pt

ani = FuncAnimation(fig, animate, frames =len(data), interval=100, repeat = False)

plt.show()

# %%
#bài 13 biểu đồ ngang thống kê doanh số
import matplotlib.pyplot as plt

sanphams =['Sua','Gao','Duong', 'Nuoc ngot', 'Muoi']

doanhso=[70,82,60,55,40]

_error = [5,8,7,6,4]

plt.barh(sanphams, doanhso, xerr= _error, color ='green')

plt.title('Thong ke doanh so')

plt.xlabel("Doanh so(trieu dong)")

plt.ylabel("Danh muc")

plt.show()

# %%
# bài 14 
import matplotlib.pyplot as plt

from matplotlib.animation import FuncAnimation

from random import randint

import numpy as np

fig, ax = plt.subplots()

data = np.linspace(-5,5,200)

ax.plot(data,data**2)

ax.set_xlim([-5,5])

ax.set_ylim([0,25])

# Vẽ hình tròn

circle = plt.Circle((0,0), 0.5, fc='r')

def init():

    circle.center = (-5,25)    

    ax.add_patch(circle)

    return circle

def animate(i):

    x = data[i]

    y = x**2

    circle.center = (x,y)

    return circle

ani = FuncAnimation(fig, animate, init_func=init ,frames =len(data), interval=100, repeat = False)

plt.show()

# %%
# bài 15
import matplotlib.pyplot as plt

from matplotlib.animation import FuncAnimation

from random import randint

import numpy as np

data = np.linspace(-5,5,200)

x = []

y = []

fig, ax = plt.subplots()

def animate(i):

    temp = data[i]

    x.append(temp)

    pt = temp**2

    y.append(pt)

    ax.clear()

    ax.plot(x,y)

    ax.set_xlim([-5,5])

    ax.set_ylim([0,25])

ani = FuncAnimation(fig, animate, frames =200, interval=100, repeat = False)

plt.show()
