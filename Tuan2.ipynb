# %%
import pandas as pd
df = pd.read_csv('my_sales_data.csv', encoding='unicode_escape', header=0, delimiter=',')

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...             PHONE  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...        2125557818
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...        26.47.1555
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...  +33 1 46 62 7555
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...        6265557265
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...        6505551386
#
#                     ADDRESSLINE1 ADDRESSLINE2           CITY STATE POSTALCODE  \
# ...

# %%
df.tail()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#            ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2818  12/2/2004 0:00   Shipped       4        12     2004  ...
# 2819  1/31/2005 0:00   Shipped       1         1     2005  ...
# 2820   3/1/2005 0:00  Resolved       1         3     2005  ...
# 2821  3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822   5/6/2005 0:00   On Hold       2         5     2005  ...
#
#                PHONE           ADDRESSLINE1 ADDRESSLINE2      CITY STATE  \
# 2818  (91) 555 94 44     C/ Moralzarzal, 86          NaN    Madrid   NaN
# ...

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'FULLNAME', 'DEALSIZE'],
#       dtype='object')

# %%
df.shape
# Out:
# (2823, 24)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2823, step=1)

# %%
df.dropna(how='all',inplace=True) #xoa cac dong

# %%
df.drop_duplicates(inplace=True)

# %%
df['ADDRESSLINE2'].isna().sum()
# Out:
# 2521

# %%
df['ADDRESSLINE2'].fillna('Unknown', inplace=True)
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df['TOTALPRICE'] = df['QUANTITYORDERED']*df['PRICEEACH']
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df_sub_cols=[['ORDERNUMBER','QUANTITYORDERED','PRICEEACH','SALES','TOTALPRICE']]
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df[4:9] #lay du lieu theo chi so hang(row) index=4 cho toi dong index=8
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
# 5  10/28/2003 0:00  Shipped       4        10     2003  ...
# 6  11/11/2003 0:00  Shipped       4        11     2003  ...
# 7  11/18/2003 0:00  Shipped       4        11     2003  ...
# 8   12/1/2003 0:00  Shipped       4        12     2003  ...
#
#                   ADDRESSLINE1  ADDRESSLINE2           CITY STATE POSTALCODE  \
# 4              7734 Strong St.       Unknown  San Francisco    CA        NaN
# ...

# %%
df.loc[2] #lay thong tin du lieu cua 1 dong
# Out:
# ORDERNUMBER                                10134
# QUANTITYORDERED                               41
# PRICEEACH                                  94.74
# ORDERLINENUMBER                                2
# SALES                                    3884.34
# ORDERDATE                          7/1/2003 0:00
# STATUS                                   Shipped
# QTR_ID                                         3
# MONTH_ID                                       7
# YEAR_ID                                     2003
# PRODUCTLINE                          Motorcycles
# MSRP                                          95
# PRODUCTCODE                             S10_1678
# CUSTOMERNAME                     Lyon Souveniers
# PHONE                           +33 1 46 62 7555
# ADDRESSLINE1       27 rue du Colonel Pierre Avia
# ADDRESSLINE2                             Unknown
# CITY                                       Paris
# STATE                                        NaN
# ...

# %%
df.loc[4:9]
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
# 5  10/28/2003 0:00  Shipped       4        10     2003  ...
# 6  11/11/2003 0:00  Shipped       4        11     2003  ...
# 7  11/18/2003 0:00  Shipped       4        11     2003  ...
# 8   12/1/2003 0:00  Shipped       4        12     2003  ...
# 9   1/15/2004 0:00  Shipped       1         1     2004  ...
#
# ...

# %%
df.loc[4:9, ['QUANTITYORDERED','PRICEEACH']]
# Out:
#    QUANTITYORDERED  PRICEEACH
# 4               49     100.00
# 5               36      96.66
# 6               29      86.13
# 7               48     100.00
# 8               22      98.57
# 9               41     100.00

# %%
df.iloc[2] #dung cho chi so la dang so
# Out:
# ORDERNUMBER                                10134
# QUANTITYORDERED                               41
# PRICEEACH                                  94.74
# ORDERLINENUMBER                                2
# SALES                                    3884.34
# ORDERDATE                          7/1/2003 0:00
# STATUS                                   Shipped
# QTR_ID                                         3
# MONTH_ID                                       7
# YEAR_ID                                     2003
# PRODUCTLINE                          Motorcycles
# MSRP                                          95
# PRODUCTCODE                             S10_1678
# CUSTOMERNAME                     Lyon Souveniers
# PHONE                           +33 1 46 62 7555
# ADDRESSLINE1       27 rue du Colonel Pierre Avia
# ADDRESSLINE2                             Unknown
# CITY                                       Paris
# STATE                                        NaN
# ...

# %%
df.iloc[4:9]
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
# 5  10/28/2003 0:00  Shipped       4        10     2003  ...
# 6  11/11/2003 0:00  Shipped       4        11     2003  ...
# 7  11/18/2003 0:00  Shipped       4        11     2003  ...
# 8   12/1/2003 0:00  Shipped       4        12     2003  ...
#
#                   ADDRESSLINE1  ADDRESSLINE2           CITY STATE POSTALCODE  \
# 4              7734 Strong St.       Unknown  San Francisco    CA        NaN
# ...

# %%
df.iloc[:10]
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# ...

# %%
df.iloc[2:9,2:5] #lấy dữ liệu từ dòng 2 tới dòng 8, cột 2 tới cột 4
# Out:
#    PRICEEACH  ORDERLINENUMBER    SALES
# 2      94.74                2  3884.34
# 3      83.26                6  3746.70
# 4     100.00               14  5205.27
# 5      96.66                1  3479.76
# 6      86.13                9  2497.77
# 7     100.00                1  5512.32
# 8      98.57                2  2168.54

# %%
df.sort_values(by='SALES', ascending=False) #sắp xếp theo chiều giảm dần của cột SALES
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 598         10407               76     100.00                2  14082.80
# 744         10322               50     100.00                6  12536.50
# 53          10424               50     100.00                6  12001.00
# 1062        10412               60     100.00                9  11887.80
# 104         10403               66     100.00                9  11886.60
# ...           ...              ...        ...              ...       ...
# 1818        10419               15      42.67                7    640.05
# 1551        10280               20      28.88               12    577.60
# 2044        10408               15      36.93                1    553.95
# 1287        10407                6      90.19                3    541.14
# 2249        10425               11      43.83                6    482.13
#
#            ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.sort_values(by=['QUANTITYORDERED','PRICEEACH'], ascending=[False, True]) #sắp xếp theo chiều giảm dần cột QUANTITYORDERED , tăng dần cột PRICEEACH

# %%
df[df['SALES']>5000]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 4           10159               49      100.0               14  5205.27
# 7           10188               48      100.0                1  5512.32
# 20          10341               41      100.0                9  7737.93
# 25          10417               66      100.0                2  7516.08
# 26          10103               26      100.0               11  5404.62
# ...           ...              ...        ...              ...      ...
# 2685        10361               44      100.0               10  5001.92
# 2686        10375               44      100.0               11  5208.72
# 2689        10401               77       92.0                9  7084.00
# 2715        10397               48      100.0                3  5192.64
# 2820        10386               43      100.0                4  5417.57
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df[(df['SALES']>5000) & (df['QUANTITYORDERED']>40)]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 4           10159               49      100.0               14   5205.27
# 7           10188               48      100.0                1   5512.32
# 20          10341               41      100.0                9   7737.93
# 25          10417               66      100.0                2   7516.08
# 30          10150               45      100.0                8  10993.50
# ...           ...              ...        ...              ...       ...
# 2685        10361               44      100.0               10   5001.92
# 2686        10375               44      100.0               11   5208.72
# 2689        10401               77       92.0                9   7084.00
# 2715        10397               48      100.0                3   5192.64
# 2820        10386               43      100.0                4   5417.57
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.loc[df['SALES']>5000]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 4           10159               49      100.0               14  5205.27
# 7           10188               48      100.0                1  5512.32
# 20          10341               41      100.0                9  7737.93
# 25          10417               66      100.0                2  7516.08
# 26          10103               26      100.0               11  5404.62
# ...           ...              ...        ...              ...      ...
# 2685        10361               44      100.0               10  5001.92
# 2686        10375               44      100.0               11  5208.72
# 2689        10401               77       92.0                9  7084.00
# 2715        10397               48      100.0                3  5192.64
# 2820        10386               43      100.0                4  5417.57
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.loc[(df['SALES']>5000) & (df['QUANTITYORDERED']>40)]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 4           10159               49      100.0               14   5205.27
# 7           10188               48      100.0                1   5512.32
# 20          10341               41      100.0                9   7737.93
# 25          10417               66      100.0                2   7516.08
# 30          10150               45      100.0                8  10993.50
# ...           ...              ...        ...              ...       ...
# 2685        10361               44      100.0               10   5001.92
# 2686        10375               44      100.0               11   5208.72
# 2689        10401               77       92.0                9   7084.00
# 2715        10397               48      100.0                3   5192.64
# 2820        10386               43      100.0                4   5417.57
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.loc[df['PRICEEACH']<65, 'FLAG'] ='CHEAP'
df.loc[df['PRICEEACH']>65, 'FLAG'] ='EXPENSIVE'
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# ...

# %%
# viết hàm tổng hợp
import numpy as np
df.aggregate({'QUANTITYORDERED':['sum','min'], 'PRICEEACH' : ['min', 'max', np.mean], 'SALES':['sum', np.mean]})
# Out:
#       QUANTITYORDERED   PRICEEACH         SALES
# max               NaN  100.000000           NaN
# mean              NaN   83.658544  3.553889e+03
# min               6.0   26.880000           NaN
# sum           99067.0         NaN  1.003263e+07

# %%
#gom nhóm
df.groupby('DEALSIZE')['QUANTITYORDERED','PRICEEACH','SALES'].agg(['count','min','max','mean','sum'])
# Out:
# <ipython-input-7-60d37e3f612c>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('DEALSIZE')['QUANTITYORDERED','PRICEEACH','SALES'].agg(['count','min','max','mean','sum'])
#          QUANTITYORDERED                           PRICEEACH                \
#                    count min max       mean    sum     count    min    max
# DEALSIZE
# Large                157  29  97  47.222930   7414       157  88.75  100.0
# Medium              1384  20  66  37.947254  52519      1384  55.72  100.0
# Small               1282   6  64  30.525741  39134      1282  26.88  100.0
#
#                                SALES                                  \
#                mean        sum count      min       max         mean
# DEALSIZE
# Large     99.799554   15668.53   157  7016.31  14082.80  8293.753248
# Medium    95.361741  131980.65  1384  3002.40   6996.42  4398.433699
# ...
