# %%
# QUÁ TRÌNH EDA =
#Bước 1: Xử lý dữ liệu cơ bản theo yêu cầu
1.1 Đọc dữ liệu
1.2 Loại bỏ dòng dữ liệu rỗng
1.3 Loại bỏ dữ liệu trùng, biết rằng dữ liệu trùng là dữ liệu có đồng thời ORDERNUMBER và ORDERDATE như nhau
1.4 Kiểm tra các dữ liệu thiếu và điền thiếu bằng chart
    1.4.1 Với dữ liệu định tính thì thay bằng Unknown
    1.4.2 Với dữ liệu định lượng thì thay bằng giá trị trung bình, nếu là dữ liệu time series thì dùng interpolate
1.5 Tách cột FULLNAME thành CONTACTLASTNAME và CONTACTFIRSTNAME, sau đó xóa cột FULLNAME
1.6 Lưu dữ liệu đã xử lý thành file với tên processed_sales_data với header là tên cột và phân cách (delimiter) là dấu phẩy

#Bước 2: Công ty cần phân tích dữ liệu bán hàng.
Hãy thực hiện EDA cho dữ liệu để khai thác các thông tin về dữ liệu SALES trên nhiều góc độ
Yêu cầu

# %%
1. Dữ liệu định tính
1.1 Một biến
    1.1.1 Hãy cho biết số lượng đơn hàng theo năm (YEAR_ID)
        (*) Gợi ý: Trực quan với biểu đồ cột (bar)
    1.1.1.bis Hãy cho biết số lượng sản phẩm bán theo năm (YEAR_ID)  
    1.1.2 Hãy cho biết tỉ lệ số đơn hàng theo DEALSIZE
        (*) Gợi ý: Trực quan với biểu đồ tròn (pie)
    1.1.3 Hãy cho biết tỉ lệ giá trị SALES theo DEALSIZE
    1.1.4 Hãy cho biết tỉ lệ tình trạng đơn hàng (STATUS)
    1.1.5 Hãy cho biết tỉ lệ số đơn hàng theo COUNTRY
    1.1.6 Hãy cho biết tỉ lệ số đơn hàng theo CITY    
    1.1.7 Hãy cho biết tổng giá trị SALES theo ngày
        (*) Gợi ý: Biểu đồ line (Ox = date, Oy = tổng giá trị SALES)
    1.1.8 Hãy cho biết giá trị SALES trung bình theo tháng năm
    1.1.9 Hãy cho biết số lượng hóa đơn theo (tháng, năm)
        (*) Gợi ý: Biểu đồ line (Ox = {tháng, năm}, Oy = số lượng hóa đơn)
    1.1.10 Hãy cho biết số lượng hóa đơn theo (quý, năm)
        (*) Gợi ý: Biểu đồ line (Ox = {quý, năm}, Oy = số lượng hóa đơn)
1.2 Đa biến
(*) Gợi ý: Dùng biểu đồ cột so sánh
    1.2.1 Hãy cho biết trạng thái số đơn hàng (STATUS) theo nhóm các năm (YEAR_ID)
        (*) Gợi ý: Biểu đồ so sánh un-stacked (vertical)
    1.2.2  Hãy cho biết số lượng đơn hàng theo nhóm các quý (QTR_ID) theo năm (YEAR_ID)
        (*) Gợi ý: Biểu đồ so sánh un-stacked (vertical)  
    1.2.3 Hãy cho biết số lượng hóa đơn giữa các nhóm DEALSIZE theo YEAR_ID
        (*) Gợi ý: Biều đồ so sánh stacked (horizontal)
    1.2.4 Hãy cho biết trung bình SALES các nhóm STATUS theo DEALSIZE
    1.2.5 Hãy cho biết tổng số lượng sản phẩm các nhóm DEALSIZE theo vùng kinh tế (TERRITORY)

# %%
2. Dữ liệu định lượng
2.1 Một biến
    2.1.1 Mô tả dữ liệu của QUANTITYORDERED, PRICEEACH, SALES
    2.1.2 Phân phối (PairPlot, Histogram) của QUANTITYORDERED, PRICEEACH, SALES
        2.1.2.1 Phân phối (PairPlot, Histogram) của QUANTITYORDERED, PRICEEACH, SALES theo nhóm DEALSIZE
    2.1.3 Biểu diễn (Boxplot) của QUANTITYORDERED, PRICEEACH, SALES
        2.1.3.1 Biểu diễn (Boxplot) của QUANTITYORDERED theo nhóm DEALSIZE
        2.1.3.2 Biểu diễn (Boxplot) của PRICEEACH theo nhóm DEALSIZE
        2.1.3.3 Biểu diễn (Boxplot) của SALES theo nhóm DEALSIZE
    2.1.4 Độ xiên của phân phối (Skew) của QUANTITYORDERED, PRICEEACH, SALES
    2.1.5 Độ nhọn của phân phối (Kutorsis) của QUANTITYORDERED, PRICEEACH, SALES
   # 2.1.6 Kiểm tra tính chuẩn (Normal distribution) của QUANTITYORDERED, PRICEEACH, SALES

# %%
import pandas as pd
df = pd.read_csv('my_sales_data.csv', encoding='unicode_escape', header=0, delimiter=',')

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...             PHONE  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...        2125557818
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...        26.47.1555
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...  +33 1 46 62 7555
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...        6265557265
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...        6505551386
#
#                     ADDRESSLINE1 ADDRESSLINE2           CITY STATE POSTALCODE  \
# 0        897 Long Airport Avenue          NaN            NYC    NY      10022
# 1             59 rue de l'Abbaye          NaN          Reims   NaN      51100
# 2  27 rue du Colonel Pierre Avia          NaN          Paris   NaN      75508
# 3             78934 Hillside Dr.          NaN       Pasadena    CA      90003
# 4                7734 Strong St.          NaN  San Francisco    CA        NaN
#
#   COUNTRY TERRITORY        FULLNAME DEALSIZE
# 0     USA       NaN         Yu Kwai    Small
# 1  France      EMEA    Henriot Paul    Small
# 2  France      EMEA  DaCunha Daniel   Medium
# 3     USA       NaN     Young Julie   Medium
# 4     USA       NaN     Brown Julie   Medium
#
# [5 rows x 24 columns]

# %%
#1.2 Loại bỏ dòng dữ liệu rỗng
df.dropna(how='all',inplace=True)

# %%
#1.3 Loại bỏ dữ liệu trùng, biết rằng dữ liệu trùng là dữ liệu có đồng thời ORDERNUMBER và ORDERDATE như nhau
df.drop_duplicates(inplace=True) # định nghĩ trên 2 cột bị trùng
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0      2/24/2003 0:00   Shipped       1         2     2003  ...
# 1       5/7/2003 0:00   Shipped       2         5     2003  ...
# 2       7/1/2003 0:00   Shipped       3         7     2003  ...
# 3      8/25/2003 0:00   Shipped       3         8     2003  ...
# 4     10/10/2003 0:00   Shipped       4        10     2003  ...
# ...               ...       ...     ...       ...      ...  ...
# 2818   12/2/2004 0:00   Shipped       4        12     2004  ...
# 2819   1/31/2005 0:00   Shipped       1         1     2005  ...
# 2820    3/1/2005 0:00  Resolved       1         3     2005  ...
# 2821   3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822    5/6/2005 0:00   On Hold       2         5     2005  ...
#
#                  PHONE                   ADDRESSLINE1 ADDRESSLINE2  \
# 0           2125557818        897 Long Airport Avenue          NaN
# 1           26.47.1555             59 rue de l'Abbaye          NaN
# 2     +33 1 46 62 7555  27 rue du Colonel Pierre Avia          NaN
# 3           6265557265             78934 Hillside Dr.          NaN
# 4           6505551386                7734 Strong St.          NaN
# ...                ...                            ...          ...
# 2818    (91) 555 94 44             C/ Moralzarzal, 86          NaN
# 2819        981-443655                    Torikatu 38          NaN
# 2820    (91) 555 94 44             C/ Moralzarzal, 86          NaN
# 2821        61.77.6555          1 rue Alsace-Lorraine          NaN
# 2822        6175559555             8616 Spinnaker Dr.          NaN
#
#                CITY STATE POSTALCODE  COUNTRY TERRITORY          FULLNAME  \
# 0               NYC    NY      10022      USA       NaN           Yu Kwai
# 1             Reims   NaN      51100   France      EMEA      Henriot Paul
# 2             Paris   NaN      75508   France      EMEA    DaCunha Daniel
# 3          Pasadena    CA      90003      USA       NaN       Young Julie
# 4     San Francisco    CA        NaN      USA       NaN       Brown Julie
# ...             ...   ...        ...      ...       ...               ...
# 2818         Madrid   NaN      28034    Spain      EMEA      Freyre Diego
# 2819           Oulu   NaN      90110  Finland      EMEA  Koskitalo Pirkko
# 2820         Madrid   NaN      28034    Spain      EMEA      Freyre Diego
# 2821       Toulouse   NaN      31000   France      EMEA    Roulet Annette
# 2822         Boston    MA      51003      USA       NaN      Yoshido Juri
#
#      DEALSIZE
# 0       Small
# 1       Small
# 2      Medium
# 3      Medium
# 4      Medium
# ...       ...
# 2818    Small
# 2819   Medium
# 2820   Medium
# 2821    Small
# 2822   Medium
#
# [2823 rows x 24 columns]

# %%
#1.4 Kiểm tra các dữ liệu thiếu và điền thiếu bằng chart
   # 1.4.1 Với dữ liệu định tính thì thay bằng Unknown
   # 1.4.2 Với dữ liệu định lượng thì thay bằng giá trị trung bình, nếu là dữ liệu time series thì dùng interpolate
import seaborn as sns 
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.heatmap(df.isna().transpose(), cmap='YlGnBu', cbar_kws={'label':'Missing Data'})

plt.savefig('my_missing_data.png', dpi=100)

# %%
#1.4dien thieu
df['ADDRESSLINE2'].fillna('Unknown', inplace=True)
df['TERRITORY'].fillna('Unknown', inplace=True)
df['STATE'].fillna('Unknown', inplace=True)
df['POSTALCODE'].fillna('0', inplace=True)
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2358        10199               29      38.40                1  1113.60
# 2532        10397               32      80.55                5  2577.60
# 2554        10352               23     100.00                3  2352.67
# 2692        10118               36     100.00                1  4219.20
# 2733        10294               45     100.00                1  4692.60
#
#             ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0      2/24/2003 0:00  Shipped       1         2     2003  ...
# 1       5/7/2003 0:00  Shipped       2         5     2003  ...
# 2       7/1/2003 0:00  Shipped       3         7     2003  ...
# 3      8/25/2003 0:00  Shipped       3         8     2003  ...
# 4     10/10/2003 0:00  Shipped       4        10     2003  ...
# ...               ...      ...     ...       ...      ...  ...
# 2358   12/1/2003 0:00  Shipped       4        12     2003  ...
# 2532   3/28/2005 0:00  Shipped       1         3     2005  ...
# 2554   12/3/2004 0:00  Shipped       4        12     2004  ...
# 2692   4/21/2003 0:00  Shipped       2         4     2003  ...
# 2733   9/10/2004 0:00  Shipped       3         9     2004  ...
#
#                  PHONE                   ADDRESSLINE1 ADDRESSLINE2  \
# 0           2125557818        897 Long Airport Avenue      Unknown
# 1           26.47.1555             59 rue de l'Abbaye      Unknown
# 2     +33 1 46 62 7555  27 rue du Colonel Pierre Avia      Unknown
# 3           6265557265             78934 Hillside Dr.      Unknown
# 4           6505551386                7734 Strong St.      Unknown
# ...                ...                            ...          ...
# 2358        3105553722              3675 Furth Circle      Unknown
# 2532        61.77.6555          1 rue Alsace-Lorraine      Unknown
# 2554        6175558428              16780 Pompton St.      Unknown
# 2692     (93) 203 4555         Rambla de Catalu¤a, 23      Unknown
# 2733        6175557555             7635 Spinnaker Dr.      Unknown
#
#                CITY    STATE POSTALCODE COUNTRY TERRITORY          FULLNAME  \
# 0               NYC       NY      10022     USA   Unknown           Yu Kwai
# 1             Reims  Unknown      51100  France      EMEA      Henriot Paul
# 2             Paris  Unknown      75508  France      EMEA    DaCunha Daniel
# 3          Pasadena       CA      90003     USA   Unknown       Young Julie
# 4     San Francisco       CA          0     USA   Unknown       Brown Julie
# ...             ...      ...        ...     ...       ...               ...
# 2358        Burbank       CA      94019     USA   Unknown    Thompson Steve
# 2532       Toulouse  Unknown      31000  France      EMEA    Roulet Annette
# 2554     Brickhaven       MA      58339     USA   Unknown     Taylor Leslie
# 2692      Barcelona  Unknown       8022   Spain      EMEA  Saavedra Eduardo
# 2733     Brickhaven       MA      58339     USA   Unknown    Barajas Miguel
#
#      DEALSIZE
# 0       Small
# 1       Small
# 2      Medium
# 3      Medium
# 4      Medium
# ...       ...
# 2358    Small
# 2532    Small
# 2554    Small
# 2692   Medium
# 2733   Medium
#
# [307 rows x 24 columns]

# %%
#1.5
df[['CONTACTLASTNAME','CONTACTFIRSTNAME']] = df['FULLNAME'].str.split(' ', expand=True)
df = df.drop('FULLNAME', axis=1)
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2358        10199               29      38.40                1  1113.60
# 2532        10397               32      80.55                5  2577.60
# 2554        10352               23     100.00                3  2352.67
# 2692        10118               36     100.00                1  4219.20
# 2733        10294               45     100.00                1  4692.60
#
#             ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0      2/24/2003 0:00  Shipped       1         2     2003  ...
# 1       5/7/2003 0:00  Shipped       2         5     2003  ...
# 2       7/1/2003 0:00  Shipped       3         7     2003  ...
# 3      8/25/2003 0:00  Shipped       3         8     2003  ...
# 4     10/10/2003 0:00  Shipped       4        10     2003  ...
# ...               ...      ...     ...       ...      ...  ...
# 2358   12/1/2003 0:00  Shipped       4        12     2003  ...
# 2532   3/28/2005 0:00  Shipped       1         3     2005  ...
# 2554   12/3/2004 0:00  Shipped       4        12     2004  ...
# 2692   4/21/2003 0:00  Shipped       2         4     2003  ...
# 2733   9/10/2004 0:00  Shipped       3         9     2004  ...
#
#                        ADDRESSLINE1  ADDRESSLINE2           CITY    STATE  \
# 0           897 Long Airport Avenue       Unknown            NYC       NY
# 1                59 rue de l'Abbaye       Unknown          Reims  Unknown
# 2     27 rue du Colonel Pierre Avia       Unknown          Paris  Unknown
# 3                78934 Hillside Dr.       Unknown       Pasadena       CA
# 4                   7734 Strong St.       Unknown  San Francisco       CA
# ...                             ...           ...            ...      ...
# 2358              3675 Furth Circle       Unknown        Burbank       CA
# 2532          1 rue Alsace-Lorraine       Unknown       Toulouse  Unknown
# 2554              16780 Pompton St.       Unknown     Brickhaven       MA
# 2692         Rambla de Catalu¤a, 23       Unknown      Barcelona  Unknown
# 2733             7635 Spinnaker Dr.       Unknown     Brickhaven       MA
#
#      POSTALCODE COUNTRY TERRITORY DEALSIZE CONTACTLASTNAME CONTACTFIRSTNAME
# 0         10022     USA   Unknown    Small              Yu             Kwai
# 1         51100  France      EMEA    Small         Henriot             Paul
# 2         75508  France      EMEA   Medium         DaCunha           Daniel
# 3         90003     USA   Unknown   Medium           Young            Julie
# 4             0     USA   Unknown   Medium           Brown            Julie
# ...         ...     ...       ...      ...             ...              ...
# 2358      94019     USA   Unknown    Small        Thompson            Steve
# 2532      31000  France      EMEA    Small          Roulet          Annette
# 2554      58339     USA   Unknown    Small          Taylor           Leslie
# 2692       8022   Spain      EMEA   Medium        Saavedra          Eduardo
# 2733      58339     USA   Unknown   Medium         Barajas           Miguel
#
# [307 rows x 25 columns]

# %%
#1.6 Lưu dữ liệu đã xử lý thành file với tên processed_sales_data với header là tên cột và phân cách (delimiter) là dấu phẩy
df.to_csv('processed_sales_data.csv', sep =',', encoding='utf-8', index=False)

# %%
# buoc 2: EDA
#1.1.1 Hãy cho biết số lượng đơn hàng theo năm (YEAR_ID)
from numpy  import count_nonzero
sns.barplot(x='YEAR_ID', y='ORDERNUMBER', data=df, ci=None, estimator=count_nonzero)
plt.show()

# %%
#1.1.1.bis Hãy cho biết số lượng sản phẩm bán theo năm (YEAR_ID)
from numpy  import sum
sns.barplot(x='YEAR_ID', y='QUANTITYORDERED', data=df, ci=None, estimator=sum)
plt.show()

# %%
#1.1.2 Hãy cho biết tỉ lệ số đơn hàng theo DEALSIZE
# (*) Gợi ý: Trực quan với biểu đồ tròn (pie)
gb = df.groupby(['DEALSIZE'])['ORDERNUMBER'].agg(['count'])
#gb
data = list(gb['count'])
labels = gb.index

colors = sns.color_palette('pastel')
plt.pie(data, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True)
plt.show()

# %%
# 1.1.3 Hãy cho biết tỉ lệ giá trị SALES theo DEALSIZE
gb = df.groupby(['DEALSIZE'])['SALES'].agg(['sum'])
#gb
data = list(gb['sum'])
labels = gb.index

colors = sns.color_palette('pastel')
plt.pie(data, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True)
plt.show()

# %%
# 1.1.4 Hãy cho biết tỉ lệ tình trạng đơn hàng (STATUS)
gb = df.groupby(['STATUS']).agg(['sum'])
gb
# Out:
#            ORDERNUMBER QUANTITYORDERED  PRICEEACH ORDERLINENUMBER       SALES  \
#                    sum             sum        sum             sum         sum
# STATUS
# Cancelled       613878            2038    5061.69             482   194487.48
# Disputed        145795             597    1252.26              42    72212.86
# In Process      427330            1490    3251.96             224   144729.96
# On Hold         457496            1879    3773.99             282   178979.19
# Resolved        485647            1660    3753.24             334   150718.28
# Shipped       26830235           91403  219074.93           16890  9291501.08
#
#                                                     ORDERDATE QTR_ID MONTH_ID  \
#                                                           sum    sum      sum
# STATUS
# Cancelled   10/23/2003 0:005/7/2004 0:006/1/2004 0:006/1/2...    152      410
# Disputed    5/13/2005 0:005/13/2005 0:005/13/2005 0:005/13...     28       67
# In Process  5/31/2005 0:005/31/2005 0:005/31/2005 0:005/31...     82      205
# On Hold     5/6/2005 0:0011/19/2004 0:004/22/2005 0:004/22...    100      232
# Resolved    10/21/2003 0:0010/21/2003 0:0010/21/2003 0:001...     95      235
# Shipped     2/24/2003 0:005/7/2003 0:007/1/2003 0:008/25/2...   7215    18873
#
#             YEAR_ID                                        PRODUCTLINE  \
#                 sum                                                sum
# STATUS
# Cancelled    120224  Classic CarsClassic CarsClassic CarsClassic Ca...
# Disputed      28070  MotorcyclesMotorcyclesMotorcyclesMotorcyclesCl...
# In Process    82205  Classic CarsClassic CarsTrucks and BusesTrucks...
# On Hold       88214  Classic CarsClassic CarsClassic CarsVintage Ca...
# Resolved      94211  Classic CarsTrucks and BusesTrucks and BusesCl...
# Shipped     5243846  MotorcyclesMotorcyclesMotorcyclesMotorcyclesMo...
#
#               MSRP                                        PRODUCTCODE  \
#                sum                                                sum
# STATUS
# Cancelled     5759  S10_4757S10_4757S12_1099S12_3380S12_3990S12_46...
# Disputed      1529  S10_1678S10_2016S10_4698S12_2823S18_1129S18_19...
# In Process    4011  S10_1949S10_4962S12_1666S12_4473S18_1097S18_13...
# On Hold       4237  S10_4757S10_4962S18_1589S18_1749S18_2248S18_23...
# Resolved      4290  S10_4962S12_1666S18_1097S18_1589S18_1662S18_16...
# Shipped     264494  S10_1678S10_1678S10_1678S10_1678S10_1678S10_16...
#
#                                                  CUSTOMERNAME  \
#                                                           sum
# STATUS
# Cancelled   Scandinavian Gift IdeasLand of Toys Inc.UK Col...
# Disputed    Euro Shopping ChannelEuro Shopping ChannelEuro...
# In Process  Euro Shopping ChannelLa Rochelle GiftsEuro Sho...
# On Hold     Gifts4AllAges.comVolvo Model Replicas, CoThe S...
# Resolved    Mini Auto WerkeMini Auto WerkeMini Auto WerkeT...
# Shipped     Land of Toys Inc.Reims CollectablesLyon Souven...
#
#                                                         PHONE  \
#                                                           sum
# STATUS
# Cancelled   0695-34 65552125557818(171) 555-2282(171) 555-...
# Disputed    (91) 555 94 44(91) 555 94 44(91) 555 94 44(91)...
# In Process  (91) 555 94 4440.67.8555(91) 555 94 4440.67.85...
# On Hold     61755595550921-12 3555408555365940855536594085...
# Resolved    7675-35557675-35557675-3555626555726531 12 355...
# Shipped     212555781826.47.1555+33 1 46 62 75556265557265...
#
#                                                  ADDRESSLINE1  \
#                                                           sum
# STATUS
# Cancelled   ?kergatan 24897 Long Airport AvenueBerkeley Ga...
# Disputed    C/ Moralzarzal, 86C/ Moralzarzal, 86C/ Moralza...
# In Process  C/ Moralzarzal, 8667, rue des Cinquante Otages...
# On Hold     8616 Spinnaker Dr.Berguvsvgen  83086 Ingle Ln...
# Resolved    Kirchgasse 6Kirchgasse 6Kirchgasse 678934 Hill...
# Shipped     897 Long Airport Avenue59 rue de l'Abbaye27 ru...
#
#                                                          CITY  \
#                                                           sum
# STATUS
# Cancelled   BorasNYCLiverpoolLiverpoolLiverpoolLiverpoolLi...
# Disputed    MadridMadridMadridMadridKobenhavnKobenhavnMadr...
# In Process  MadridNantesMadridNantesMadridAllentownAllento...
# On Hold     BostonLuleSan JoseSan JoseSan JoseLuleLuleNewa...
# Resolved    GrazGrazGrazPasadenaKobenhavnMadridPasadenaPas...
# Shipped     NYCReimsParisPasadenaSan FranciscoBurlingameLi...
#
#                                                       COUNTRY  \
#                                                           sum
# STATUS
# Cancelled   SwedenUSAUKUKUKUKUKUKSwedenSpainUKUKUKSwedenUS...
# Disputed    SpainSpainSpainSpainDenmarkDenmarkSpainDenmark...
# In Process  SpainFranceSpainFranceSpainUSAUSAAustraliaFran...
# On Hold     USASwedenUSAUSAUSASwedenSwedenUSAUSAUSAUSASwed...
# Resolved    AustriaAustriaAustriaUSADenmarkSpainUSAUSAUSAD...
# Shipped     USAFranceFranceUSAUSAUSAFranceNorwayUSAFranceA...
#
#                                                      FULLNAME  \
#                                                           sum
# STATUS
# Cancelled   Larsson MariaYu KwaiDevon ElizabethDevon Eliza...
# Disputed    Freyre DiegoFreyre DiegoFreyre DiegoFreyre Die...
# In Process  Freyre DiegoLabrune JanineFreyre DiegoLabrune ...
# On Hold     Yoshido JuriBerglund ChristinaFrick SueFrick S...
# Resolved    Mendel RolandMendel RolandMendel RolandYoung J...
# Shipped     Yu KwaiHenriot PaulDaCunha DanielYoung JulieBr...
#
#                                                      DEALSIZE
#                                                           sum
# STATUS
# Cancelled   MediumSmallMediumSmallSmallMediumMediumMediumM...
# Disputed    LargeMediumLargeMediumLargeLargeSmallLargeMedi...
# In Process  LargeMediumLargeMediumLargeMediumSmallMediumMe...
# On Hold     SmallMediumLargeLargeMediumMediumSmallMediumMe...
# Resolved    MediumMediumMediumSmallSmallSmallMediumLargeMe...
# Shipped     SmallSmallMediumMediumMediumMediumSmallMediumS...

# %%
# 1.1.5 Hãy cho biết tỉ lệ số đơn hàng theo COUNTRY
gb = df.groupby(['COUNTRY'])['ORDERNUMBER'].agg(['count'])
#gb
data = list(gb['count'])
labels = gb.index

colors = sns.color_palette('pastel')
plt.pie(data, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True)
plt.show()

# %%
#   1.1.6 Hãy cho biết tỉ lệ số đơn hàng theo CITY 
gb = df.groupby(['CITY'])['ORDERNUMBER'].agg(['count'])
gb
# Out:
#               count
# CITY
# Aaarhus          27
# Allentown        31
# Barcelona        23
# Bergamo          48
# Bergen           29
# ...             ...
# Toulouse         20
# Tsawassen        26
# Vancouver        22
# Versailles       18
# White Plains     26
#
# [73 rows x 1 columns]

# %%
#1.7 Hãy cho biết tổng giá trị SALES theo ngày
sns.lineplot(x='ORDERDATE', y='SALES', data = df, estimator=sum)
plt.show()

# %%
#
sns.lineplot(x='MONTH_ID', y='SALES', data = df, hue='YEAR_ID')
plt.show()

# %%
#1.1.9 Hãy cho biết số lượng hóa đơn theo (tháng, năm)
sns.lineplot(x='MONTH_ID', y='ORDERNUMBER', estimator=count_nonzero, data = df, hue='YEAR_ID')
plt.show()

# %%
# 1.1.10 Hãy cho biết số lượng hóa đơn theo (quý, năm)
sns.lineplot(x='QTR_ID', y='ORDERNUMBER', estimator=count_nonzero, data = df, hue='YEAR_ID')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-9345afe0f9e9> in <module>
#       1 # 1.1.10 Hãy cho biết số lượng hóa đơn theo (quý, năm)
# ----> 2 sns.lineplot(x='QTR_ID', y='ORDERNUMBER', estimator=count_nonzero, data = df, hue='YEAR_ID')
#       3 plt.show()
#
# NameError: name 'sns' is not defined

# %%
#1.2 Đa biến
#(*) Gợi ý: Dùng biểu đồ cột so sánh
    #1.2.1 Hãy cho biết trạng thái số đơn hàng (STATUS) theo nhóm các năm (YEAR_ID)
       # (*) Gợi ý: Biểu đồ so sánh un-stacked (vertical)
sns.barplot(x='STATUS', y='ORDERNUMBER', hue='YEAR_ID', data=df, ci=None, estimator=count_nonzero)

# %%
# 1.2.2  Hãy cho biết số lượng đơn hàng theo nhóm các quý (QTR_ID) theo năm (YEAR_ID)
sns.barplot(x='QTR_ID', y='ORDERNUMBER',hue='YEAR_ID', data=df, ci=None, estimator=count_nonzero)

# %%
#1.2.3
gb = df.groupby(['DEALSIZE','YEAR_ID'])['ORDERNUMBER'].count().unstack()
gb.plot(kind='barh', stacked=True)
plt.show()

# %%
# 1.2.4 Hãy cho biết trung bình SALES các nhóm STATUS theo DEALSIZE
gb = df.groupby(['DEALSIZE','YEAR_ID'])['ORDERNUMBER'].count().unstack()
gb.plot(kind='bar', stacked=True)
plt.show()

# %%
#Dữ liệu định lượng
#2.1 Một biến 
#  2.1.1 Mô tả dữ liệu của QUANTITYORDERED, PRICEEACH, SALES

# %%
#2.1 Một biến 
#2.1.1 Mô tả dữ liệu của QUANTITYORDERED, PRICEEACH, SALES 
#2.1.1.1 Mô tả dữ liệu QUANTITYORDERED theo nhóm DEALSIZE 
#2.1.2 Phân phối 2.1.2.1 Vẽ biểu đồ Historgame của QUANTITYORDERED 
#2.1.2.2 Vẽ biểu đồ JointPlot của QUANTITYORDERED 
#2.1.2.0 Vẽ biểu đồ PairPlot của QUANTITYORDERED, PRICEEACH, SALES 
#2.1.2.1 Phân phối (PairPlot, Histogram) của QUANTITYORDERED, PRICEEACH, SALES theo nhóm DEALSIZE 
#2.1.3 Biểu diễn (Boxplot, Violin) của QUANTITYORDERED 
#2.1.3.0 Biểu diễn (Boxplot) của QUANTITYORDERED, PRICEEACH, SALES 
#2.1.3.1 Biểu diễn (Boxplot) của QUANTITYORDERED theo nhóm DEALSIZE 
#2.1.3.2 Biểu diễn (Boxplot) của PRICEEACH theo năm, nhóm DEALSIZE 
#2.1.3.3 Biểu diễn (Boxplot) của SALES theo nhóm DEALSIZE 
#2.1.4 Độ xiên của phân phối (Skew) của QUANTITYORDERED, PRICEEACH, SALES 
#2.1.5 Độ nhọn của phân phối (Kutorsis) của QUANTITYORDERED, PRICEEACH, SALES 
#2.1.6 Kiểm tra tính chuẩn (Normal distribution) của QUANTITYORDERED, PRICEEACH, SALES

# %%
#2.1 Một biến 
#2.1.1 Mô tả dữ liệu của QUANTITYORDERED, PRICEEACH, SALES 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('my_sales_data.csv', encoding='unicode_escape', header=0, delimiter=',')
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'FULLNAME', 'DEALSIZE'],
#       dtype='object')

# %%
#2.1.1 Mô tả dữ liệu của QUANTITYORDERED, PRICEEACH, SALES 
df[['QUANTITYORDERED','PRICEEACH','SALES']].describe()
# Out:
#        QUANTITYORDERED    PRICEEACH         SALES
# count      2823.000000  2823.000000   2823.000000
# mean         35.092809    83.658544   3553.889072
# std           9.741443    20.174277   1841.865106
# min           6.000000    26.880000    482.130000
# 25%          27.000000    68.860000   2203.430000
# 50%          35.000000    95.700000   3184.800000
# 75%          43.000000   100.000000   4508.000000
# max          97.000000   100.000000  14082.800000

# %%
df[['PRICEEACH']].describe()
# Out:
#          PRICEEACH
# count  2823.000000
# mean     83.658544
# std      20.174277
# min      26.880000
# 25%      68.860000
# 50%      95.700000
# 75%     100.000000
# max     100.000000

# %%
df[['SALES']].describe()
# Out:
#               SALES
# count   2823.000000
# mean    3553.889072
# std     1841.865106
# min      482.130000
# 25%     2203.430000
# 50%     3184.800000
# 75%     4508.000000
# max    14082.800000

# %%
##2.1.1.1 Mô tả dữ liệu QUANTITYORDERED theo nhóm DEALSIZE 
df.groupby('DEALSIZE')['QUANTITYORDERED'].describe()
#XEM NHOM NAO BIEN dong on dinh thi tinh cv = do lech chuan/trung binh
# Vi du tinh cv(Lager)=	10.082098/47.222930
# Vi du tinh cv(Medium) = 8.443130/37.947254
# Out:
#            count       mean        std   min   25%   50%   75%   max
# DEALSIZE
# Large      157.0  47.222930  10.082098  29.0  42.0  46.0  50.0  97.0
# Medium    1384.0  37.947254   8.443130  20.0  32.0  39.0  45.0  66.0
# Small     1282.0  30.525741   8.485265   6.0  24.0  29.0  36.0  64.0

# %%
#2.1.2 Phân phối 2.1.2.1 Vẽ biểu đồ Historgame của QUANTITYORDERED 
df['QUANTITYORDERED'].hist()
#bieu do histogram cho biet xac suat
# Out:
# <AxesSubplot:>

# %%
#2.1.2.2 Vẽ biểu đồ JointPlot của QUANTITYORDERED 
sns.jointplot(data=df, x='PRICEEACH', y='QUANTITYORDERED', kind='kde', color='g')

# %%
#2.1.2.0 Vẽ biểu đồ PairPlot của QUANTITYORDERED, PRICEEACH, SALES 
sns.pairplot(df[['QUANTITYORDERED','PRICEEACH','SALES']], diag_kind='hist', kind='kde')

# %%
#2.1.2.1 Phân phối (PairPlot, Histogram) của QUANTITYORDERED, PRICEEACH, SALES theo nhóm DEALSIZE 
sns.pairplot(df[['QUANTITYORDERED','PRICEEACH','SALES','DEALSIZE']], diag_kind='hist', kind='kde',hue='DEALSIZE')

plt.show()

# %%
#2.1.2.1 Phân phối (PairPlot, Histogram) của QUANTITYORDERED, PRICEEACH, SALES theo nhóm DEALSIZE 
sns.pairplot(df[['QUANTITYORDERED','PRICEEACH','SALES','DEALSIZE']],hue='DEALSIZE')

plt.show()

# %%
#ve  TREN 1 COT QUANTITYORDERED
sns.displot(df, x='QUANTITYORDERED', hue='DEALSIZE', kind='kde')
plt.show()

# %%
#2.1.3 Biểu diễn (Boxplot, Violin) của QUANTITYORDERED 
sns.boxplot(data=df['QUANTITYORDERED'])
plt.show()

# %%
#boxplot violin
_, axes =plt.subplots(nrows=1, ncols=2, sharey=True, figsize=(6,4))
sns.boxplot(data=df['QUANTITYORDERED'], ax=axes[0])
sns.violinplot(data=df['QUANTITYORDERED'], ax=axes[1])
plt.show()

# %%
# ve boxplot cho 2 bien
sns.boxplot(data=df[['QUANTITYORDERED','PRICEEACH']])
plt.show()

# %%
#2.1.3.0 Biểu diễn (Boxplot) củaQUANTITYORDERED , PRICEEACH, SALES 
sns.boxplot(data=df[['QUANTITYORDERED','PRICEEACH','SALES']])
plt.show()

# %%
#2.1.3.1 Biểu diễn (Boxplot) của QUANTITYORDERED theo nhóm DEALSIZE 
sns.boxplot(x='DEALSIZE', y='QUANTITYORDERED', data=df)
plt.show()
# dot bien dong tren large

# %%
#2.1.3.2 Biểu diễn (Boxplot) của PRICEEACH theo năm, nhóm DEALSIZE 
sns.boxplot(x='YEAR_ID', y='QUANTITYORDERED', data=df, hue='DEALSIZE')
plt.show()

# %%
# VE boxplot cho nhieu cot
sns.boxplot(data=df[['PRICEEACH','QUANTITYORDERED']])
plt.show()

# %%
#2.1.3.3 Biểu diễn (Boxplot) của SALES theo nhóm DEALSIZE 
sns.boxplot(x='DEALSIZE', y='SALES', data=df)
plt.show()

# %%
#2.1.4 Độ xiên của phân phối (Skew) của QUANTITYORDERED, PRICEEACH, SALES 
df[['QUANTITYORDERED','PRICEEACH']].skew()
# dau - lech trai
# dau + lech phai
# dua vao du lieu cai nao lech nhieu hon
# dua vao du lieu PRICEEACH lech nhieu hon  va lech sang trai
# Out:
# QUANTITYORDERED    0.362585
# PRICEEACH         -0.946649
# dtype: float64

# %%
#kiem tra do lech tren tung nhom DEALSIZE
df.groupby('DEALSIZE')[['QUANTITYORDERED','PRICEEACH']].skew()
# Out:
#           QUANTITYORDERED  PRICEEACH
# DEALSIZE
# Large            1.799082  -6.797695
# Medium          -0.167506  -1.952550
# Small            0.579202   0.051631

# %%
#2.1.5 Độ nhọn của phân phối (Kutorsis) của QUANTITYORDERED, PRICEEACH, SALES
# Out:
# QUANTITYORDERED    0.415744
# PRICEEACH         -0.374818
# dtype: float64

# %%
#kiem tra do nhon tren tung nhom DEALSIZE
df.groupby('DEALSIZE')[['QUANTITYORDERED','PRICEEACH']].kurtosis()
#ko cho tinh do nhon tren tung nhom

# %%
#2.1.6 Kiểm tra tính chuẩn (Normal distribution) của QUANTITYORDERED, PRICEEACH, SALES
import statsmodels.api as sm
sm.qqplot(df['QUANTITYORDERED'])
plt.show()
#khong ra phan phoi chuan

# %%
from scipy import stats
stats.probplot(df['QUANTITYORDERED'], plot=sns.mpl.pyplot)
plt.show()
